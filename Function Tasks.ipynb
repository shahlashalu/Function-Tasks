# %% [markdown]
# **1. Write a program that prints "Hello, How are You ? " on the console.**

# %%
a = 'Hello, How are You?'
(a)
# Out:
# 'Hello, How are You?'

# %% [markdown]
# **2. Write a program that take the user 's name and then prints a greeting message with their name.**

# %%
name = input("Enter your name: ")
print("Hello",name+",","Welcome to Python.")
# Out:
# Enter your name: shaluu
# Hello shaluu, Welcome to Python.

# %% [markdown]
# **3. Write a program that takes two numbers as input and prints their sum.**

# %%
a =  int(input('enter first number : '))
b = int(input('enter second number : '))
sum= a+b
print(sum)
# Out:
# enter first number : 34
# enter second number : 56
# 90

# %% [markdown]
# **4. Write a program that takes a string as input and prints its length.**

# %%
a = ('Hello World')
print(len(a))
# Out:
# 11

# %% [markdown]
# **5. Write a program that takes a sentence and then prints the number of words in that sentence.**

# %%
string1 = 'python is a simple programming langauge'
list1 = string1.split(" ")
print(len(list1))
print(list1)
# Out:
# 6
# ['python', 'is', 'a', 'simple', 'programming', 'langauge']

# %% [markdown]
# **6. Write a program that takes a string as input and counts the number of uppercase letters in the string.**

# %%
str07 = input("Enter a sentence : ")
count = 0
alpha = ["Q","W","E","R","T","Y","U","I","O","P","A","S","D","F","G","H","J","K","L","Z","X","C","V","B","N","M"]
for i in range(len(str07)):
    if str07[i] in alpha:
      count = count + 1
print("The given sentence has",count,"upper-case letters.")
# Out:
# Enter a sentence : Python is Easy to Understand and Learn
# The given sentence has 4 upper-case letters.

# %% [markdown]
# **7. Write a program that takes a sentence and then converts all the characters to uppercase.**

# %%
str1 = 'Python is a simple programming language and easy to understand.'
str1 = str1.upper()
str1
# Out:
# 'PYTHON IS A SIMPLE PROGRAMMING LANGUAGE AND EASY TO UNDERSTAND.'

# %% [markdown]
# **8. Write a program that takes a string as input and replaces all occurrences of the letter 'a' with the letter 'e'.**

# %%
str2 = input('Enter a string : ')
str3 =str2.replace('a','e')
print(str3)
# Out:
# Enter a string : python is a simple programming language and easy to understand.
# python is e simple progremming lenguege end eesy to understend.

# %% [markdown]
# **9. Create a program that checks if a given string is a palindrome.**

# %%
str05 = input("Enter a sentence : ")
a = []
for i in str05.lower():
  a.append(i)

for j in range(1000):
  for i in a:
    if i == " ":
      a.remove(" ")
    if i == ",":
      a.remove(",")
    if i == ".":
      a.remove(".")
    if i == "'":
      a.remove("'")
    if i == "?":
      a.remove("?")

if a == a[::-1]:
  print("The given sentence is a palindrome.")
else:
  print("The given sentence is not a palindrome.")
# Out:
# Enter a sentence : keep it up
# The given sentence is not a palindrome.

# %% [markdown]
# **10. Create a program that checks if a substring is present in a given string.**

# %%
str01 = input('Enter first string : ')
str02 = input('Enter a Substring : ')
if str02 in str01:
  print('The substring is present in the given string.')
else:
  print('The substring cannot find in the given string' )
# Out:
# Enter first string : python is a simple programming language.
# Enter a Substring : is
# The substring is present in the given string.

# %% [markdown]
# **11. Write a program that reverses the order of words in a given sentence.**

# %%
str03 = input('Enter a sentence : ')
print(str03[::-1])
# Out:
# Enter a sentence : hello,welcome to python
# nohtyp ot emoclew,olleh

# %% [markdown]
# **12. Write a program that finds the longest word in a given sentence.**

# %%
str04 = input("Enter a sentence : ")
word = str04.split(" ")
longest = [word[0]]

for i in range(1,len(word)):
  if len(word[i]) > len(longest[0]):
    del longest[0]
    longest = [word[i]]
  elif len(word[i]) == len(longest[0]):
    longest.append(word[i])

if len(longest) == 1:
  print("The longest word is : ",longest[0])
else:
  print('The longest words are : ', ", ".join(longest))
# Out:
# Enter a sentence : Python is a programming language
# The longest word is :  programming
